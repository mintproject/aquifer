# %%
import numpy as np
import flopy
import flopy.utils.binaryfile as bf
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter)
import pyvista as pv
from scipy import stats
from scipy.interpolate import interp1d

# %%
# input

case = 1 # case number # 1-3 # 1:homogeneous aquifer, 2:midly heterogeneous aquifer, 3:highly heterogeneous aquifer
hydr = 2 # hydraulic gradient [-] # range 0-2 (float)
rech = 1 # recharge rate [L3/T] # range 0-1 (float)
inic = 1 # initial concentration of contaminant [M/L3] # range 0-1 (float)
degr = 0.5 # degradation rate [M/T] # range 0-1 (float)
conc = 30 # concerned time period [T] # range 0-30 (integer)

# %%
# simulation with MODFLOW2005 & MT3DMS

MODFLOW = True
MT3MDS = True

simulation(MODFLOW, MT3MDS, case, hydr, rech, inic, degr, conc)
# Out:
# FloPy is using the following executable to run the model: MF2005.1_12/bin/mf2005dbl.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.12.00 2/3/2017
#
#  Using NAME file: aquifer.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2020/09/28  0:28:48
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2020/09/28  0:28:50
#  Elapsed run time:  2.392 Seconds
#
#   Normal termination of simulation
# FloPy is using the following executable to run the model: mt3dms5/bin/mt3dms5b.exe
# MT3DMS - Modular 3-D Multi-Species Transport Model [Version 5.30]
# Developed at University of Alabama for U.S. Department of Defense
#
# Using NAME File: aquifer.mtnam
#
# STRESS PERIOD NO.    1
#
# TIME STEP NO.    1
# FROM TIME =   0.0000     TO    30.000
#
# Transport Step:    1   Step Size:   0.000     Total Elapsed Time:   0.0000
# Transport Step:    2   Step Size:  0.1000     Total Elapsed Time:  0.10000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2015      [K,I,J]   15   26   27
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1699E-05  [K,I,J]   15   25   42
# Transport Step:    3   Step Size:  0.1000     Total Elapsed Time:  0.20000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2007      [K,I,J]   15   26   28
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1669E-05  [K,I,J]   15   25   41
# Transport Step:    4   Step Size:  0.1000     Total Elapsed Time:  0.30000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1677      [K,I,J]   15   28   28
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1371E-05  [K,I,J]   15   25   41
# Transport Step:    5   Step Size:  0.1000     Total Elapsed Time:  0.40000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1325      [K,I,J]   15   26   28
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1073E-05  [K,I,J]   15   25   42
# Transport Step:    6   Step Size:  0.1000     Total Elapsed Time:  0.50000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1095      [K,I,J]   15   41   28
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8345E-06  [K,I,J]   15   25   39
# Transport Step:    7   Step Size:  0.1000     Total Elapsed Time:  0.60000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9301E-01  [K,I,J]   15   41   28
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7153E-06  [K,I,J]   15   25   39
# Transport Step:    8   Step Size:  0.1000     Total Elapsed Time:  0.70000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7361E-01  [K,I,J]   15   35   28
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-06  [K,I,J]   15   25   44
# Transport Step:    9   Step Size:  0.1000     Total Elapsed Time:  0.80000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5786E-01  [K,I,J]   15   32   29
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4768E-06  [K,I,J]   15   25   41
# Transport Step:   10   Step Size:  0.1000     Total Elapsed Time:  0.90000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4773E-01  [K,I,J]   15   41   29
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3874E-06  [K,I,J]   15   25   44
# Transport Step:   11   Step Size:  0.1000     Total Elapsed Time:   1.0000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3866E-01  [K,I,J]   15   41   29
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-06  [K,I,J]   15   25   38
# Transport Step:   12   Step Size:  0.1000     Total Elapsed Time:   1.1000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3278E-01  [K,I,J]   15   40   30
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2682E-06  [K,I,J]   15   25   46
# Transport Step:   13   Step Size:  0.1000     Total Elapsed Time:   1.2000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2683E-01  [K,I,J]   15   26   31
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2235E-06  [K,I,J]   15   25   47
# Transport Step:   14   Step Size:  0.1000     Total Elapsed Time:   1.3000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2098E-01  [K,I,J]   15   40   30
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1639E-06  [K,I,J]   15   25   42
# Transport Step:   15   Step Size:  0.1000     Total Elapsed Time:   1.4000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1559E-01  [K,I,J]   15   40   31
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1341E-06  [K,I,J]   15   25   47
# Transport Step:   16   Step Size:  0.1000     Total Elapsed Time:   1.5000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1278E-01  [K,I,J]   15   40   31
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1043E-06  [K,I,J]   15   25   38
# Transport Step:   17   Step Size:  0.1000     Total Elapsed Time:   1.6000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1149E-01  [K,I,J]   15   40   31
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9686E-07  [K,I,J]   15   25   38
# Transport Step:   18   Step Size:  0.1000     Total Elapsed Time:   1.7000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8881E-02  [K,I,J]   15   48   33
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7823E-07  [K,I,J]   15   25   39
# Transport Step:   19   Step Size:  0.1000     Total Elapsed Time:   1.8000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7157E-02  [K,I,J]   15   28   33
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7078E-07  [K,I,J]   15   25   39
# Transport Step:   20   Step Size:  0.1000     Total Elapsed Time:   1.9000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5646E-02  [K,I,J]   15   30   33
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5215E-07  [K,I,J]   15   25   40
# Transport Step:   21   Step Size:  0.1000     Total Elapsed Time:   2.0000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5583E-02  [K,I,J]   15   49   62
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4098E-07  [K,I,J]   15   25   40
# Transport Step:   22   Step Size:  0.1000     Total Elapsed Time:   2.1000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5795E-02  [K,I,J]   15   33   63
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   11   38   51
# Transport Step:   23   Step Size:  0.1000     Total Elapsed Time:   2.2000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5335E-02  [K,I,J]   15   26   63
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   11   33   49
# Transport Step:   24   Step Size:  0.1000     Total Elapsed Time:   2.3000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5816E-02  [K,I,J]   15   33   64
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   11   38   54
# Transport Step:   25   Step Size:  0.1000     Total Elapsed Time:   2.4000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4856E-02  [K,I,J]   15   25   64
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   15   52   63
# Transport Step:   26   Step Size:  0.1000     Total Elapsed Time:   2.5000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5756E-02  [K,I,J]   15   45   65
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   11   33   51
# Transport Step:   27   Step Size:  0.1000     Total Elapsed Time:   2.6000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5240E-02  [K,I,J]   15   25   65
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   11   28   52
# Transport Step:   28   Step Size:  0.1000     Total Elapsed Time:   2.7000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5475E-02  [K,I,J]   15   28   66
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   11   35   57
# Transport Step:   29   Step Size:  0.1000     Total Elapsed Time:   2.8000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4873E-02  [K,I,J]   15   25   66
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   11   33   56
# Transport Step:   30   Step Size:  0.1000     Total Elapsed Time:   2.9000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5495E-02  [K,I,J]   15   28   67
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   11   35   57
# Transport Step:   31   Step Size:  0.1000     Total Elapsed Time:   3.0000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5509E-02  [K,I,J]   15   37   68
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    9   42   42
# Transport Step:   32   Step Size:  0.1000     Total Elapsed Time:   3.1000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5552E-02  [K,I,J]   15   27   68
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   11   35   58
# Transport Step:   33   Step Size:  0.1000     Total Elapsed Time:   3.2000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5746E-02  [K,I,J]   15   35   69
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   12   48   59
# Transport Step:   34   Step Size:  0.1000     Total Elapsed Time:   3.3000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5259E-02  [K,I,J]   15   26   69
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    9   43   48
# Transport Step:   35   Step Size:  0.1000     Total Elapsed Time:   3.4000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5557E-02  [K,I,J]   15   32   70
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    9   32   48
# Transport Step:   36   Step Size:  0.1000     Total Elapsed Time:   3.5000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5124E-02  [K,I,J]   15   25   70
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   15   52   69
# Transport Step:   37   Step Size:  0.1000     Total Elapsed Time:   3.6000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5378E-02  [K,I,J]   15   29   71
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   12   46   65
# Transport Step:   38   Step Size:  0.1000     Total Elapsed Time:   3.7000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5886E-02  [K,I,J]   15   25   71
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    9   36   54
# Transport Step:   39   Step Size:  0.1000     Total Elapsed Time:   3.8000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5457E-02  [K,I,J]   15   29   72
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   10   36   58
# Transport Step:   40   Step Size:  0.1000     Total Elapsed Time:   3.9000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5473E-02  [K,I,J]   15   25   72
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   11   35   63
# Transport Step:   41   Step Size:  0.1000     Total Elapsed Time:   4.0000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5188E-02  [K,I,J]   15   28   73
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]    9   40   54
# Transport Step:   42   Step Size:  0.1000     Total Elapsed Time:   4.1000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5408E-02  [K,I,J]   15   37   74
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   11   35   64
# Transport Step:   43   Step Size:  0.1000     Total Elapsed Time:   4.2000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5251E-02  [K,I,J]   15   49   74
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26   75
# Transport Step:   44   Step Size:  0.1000     Total Elapsed Time:   4.3000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5511E-02  [K,I,J]   15   34   75
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    9   45   56
# Transport Step:   45   Step Size:  0.1000     Total Elapsed Time:   4.4000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5065E-02  [K,I,J]   15   26   75
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    8   34   47
# Transport Step:   46   Step Size:  0.1000     Total Elapsed Time:   4.5000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5444E-02  [K,I,J]   15   44   76
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    8   37   52
# Transport Step:   47   Step Size:  0.1000     Total Elapsed Time:   4.6000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5170E-02  [K,I,J]   15   26   76
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25   77
# Transport Step:   48   Step Size:  0.1000     Total Elapsed Time:   4.7000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5247E-02  [K,I,J]   15   30   77
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    8   31   52
# Transport Step:   49   Step Size:  0.1000     Total Elapsed Time:   4.8000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5592E-02  [K,I,J]   15   51   77
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    8   31   53
# Transport Step:   50   Step Size:  0.1000     Total Elapsed Time:   4.9000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5115E-02  [K,I,J]   15   29   78
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   10   42   66
# Transport Step:   51   Step Size:  0.1000     Total Elapsed Time:   5.0000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5180E-02  [K,I,J]   15   25   78
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   14   22   73
# Transport Step:   52   Step Size:  0.1000     Total Elapsed Time:   5.1000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5159E-02  [K,I,J]   15   48   79
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   27   80
# Transport Step:   53   Step Size:  0.1000     Total Elapsed Time:   5.2000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5187E-02  [K,I,J]   15   38   80
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   14   22   74
# Transport Step:   54   Step Size:  0.1000     Total Elapsed Time:   5.3000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5094E-02  [K,I,J]   15   27   80
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26   81
# Transport Step:   55   Step Size:  0.1000     Total Elapsed Time:   5.4000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5278E-02  [K,I,J]   15   35   81
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   31   82
# Transport Step:   56   Step Size:  0.1000     Total Elapsed Time:   5.5000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4693E-02  [K,I,J]   15   27   81
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-07  [K,I,J]   11   35   72
# Transport Step:   57   Step Size:  0.1000     Total Elapsed Time:   5.6000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5102E-02  [K,I,J]   15   32   82
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   30   83
# Transport Step:   58   Step Size:  0.1000     Total Elapsed Time:   5.7000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4869E-02  [K,I,J]   15   26   82
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25   83
# Transport Step:   59   Step Size:  0.1000     Total Elapsed Time:   5.8000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5069E-02  [K,I,J]   15   30   83
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    8   35   61
# Transport Step:   60   Step Size:  0.1000     Total Elapsed Time:   5.9000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4629E-02  [K,I,J]   15   25   83
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    9   43   67
# Transport Step:   61   Step Size:  0.1000     Total Elapsed Time:   6.0000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5174E-02  [K,I,J]   15   30   84
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   10   42   72
# Transport Step:   62   Step Size:  0.1000     Total Elapsed Time:   6.1000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5432E-02  [K,I,J]   15   25   84
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   10   38   73
# Transport Step:   63   Step Size:  0.1000     Total Elapsed Time:   6.2000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4974E-02  [K,I,J]   15   28   85
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    9   42   69
# Transport Step:   64   Step Size:  0.1000     Total Elapsed Time:   6.3000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5013E-02  [K,I,J]   15   25   85
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    9   44   69
# Transport Step:   65   Step Size:  0.1000     Total Elapsed Time:   6.4000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5024E-02  [K,I,J]   15   28   86
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    9   43   70
# Transport Step:   66   Step Size:  0.1000     Total Elapsed Time:   6.5000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5094E-02  [K,I,J]   15   38   87
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   32   88
# Transport Step:   67   Step Size:  0.1000     Total Elapsed Time:   6.6000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4963E-02  [K,I,J]   15   27   87
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26   88
# Transport Step:   68   Step Size:  0.1000     Total Elapsed Time:   6.7000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5037E-02  [K,I,J]   15   35   88
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   30   89
# Transport Step:   69   Step Size:  0.1000     Total Elapsed Time:   6.8000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4674E-02  [K,I,J]   15   50   88
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25   89
# Transport Step:   70   Step Size:  0.1000     Total Elapsed Time:   6.9000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4926E-02  [K,I,J]   15   32   89
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   10   42   77
# Transport Step:   71   Step Size:  0.1000     Total Elapsed Time:   7.0000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4672E-02  [K,I,J]   15   26   89
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25   90
# Transport Step:   72   Step Size:  0.1000     Total Elapsed Time:   7.1000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4878E-02  [K,I,J]   15   30   90
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   10   42   78
# Transport Step:   73   Step Size:  0.1000     Total Elapsed Time:   7.2000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4468E-02  [K,I,J]   15   25   90
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   10   38   79
# Transport Step:   74   Step Size:  0.1000     Total Elapsed Time:   7.3000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4633E-02  [K,I,J]   15   30   91
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    9   42   75
# Transport Step:   75   Step Size:  0.1000     Total Elapsed Time:   7.4000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5244E-02  [K,I,J]   15   51   91
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24   92
# Transport Step:   76   Step Size:  0.1000     Total Elapsed Time:   7.5000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4736E-02  [K,I,J]   15   28   92
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   27   93
# Transport Step:   77   Step Size:  0.1000     Total Elapsed Time:   7.6000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4786E-02  [K,I,J]   15   25   92
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24   93
# Transport Step:   78   Step Size:  0.1000     Total Elapsed Time:   7.7000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4803E-02  [K,I,J]   15   48   93
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26   94
# Transport Step:   79   Step Size:  0.1000     Total Elapsed Time:   7.8000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4891E-02  [K,I,J]   15   38   94
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   32   95
# Transport Step:   80   Step Size:  0.1000     Total Elapsed Time:   7.9000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4696E-02  [K,I,J]   15   27   94
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26   95
# Transport Step:   81   Step Size:  0.1000     Total Elapsed Time:   8.0000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4791E-02  [K,I,J]   15   34   95
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   30   96
# Transport Step:   82   Step Size:  0.1000     Total Elapsed Time:   8.1000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4488E-02  [K,I,J]   15   50   95
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    8   39   75
# Transport Step:   83   Step Size:  9.9999E-02 Total Elapsed Time:   8.2000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4712E-02  [K,I,J]   15   32   96
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24   96
# Transport Step:   84   Step Size:  0.1000     Total Elapsed Time:   8.3000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4504E-02  [K,I,J]   15   26   96
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   10   38   85
# Transport Step:   85   Step Size:  9.9999E-02 Total Elapsed Time:   8.4000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4732E-02  [K,I,J]   15   30   97
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    9   42   81
# Transport Step:   86   Step Size:  0.1000     Total Elapsed Time:   8.5000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4028E-02  [K,I,J]   15   51   97
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24   98
# Transport Step:   87   Step Size:  0.1000     Total Elapsed Time:   8.6000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4442E-02  [K,I,J]   15   30   98
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24   98
# Transport Step:   88   Step Size:  9.9999E-02 Total Elapsed Time:   8.7000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4758E-02  [K,I,J]   15   25   98
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24   99
# Transport Step:   89   Step Size:  0.1000     Total Elapsed Time:   8.8000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4626E-02  [K,I,J]   15   48   99
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   27  100
# Transport Step:   90   Step Size:  9.9999E-02 Total Elapsed Time:   8.9000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4618E-02  [K,I,J]   15   35  100
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  100
# Transport Step:   91   Step Size:  0.1000     Total Elapsed Time:   9.0000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4661E-02  [K,I,J]   15   28  100
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  101
# Transport Step:   92   Step Size:  0.1000     Total Elapsed Time:   9.1000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4705E-02  [K,I,J]   15   38  101
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   32  102
# Transport Step:   93   Step Size:  9.9999E-02 Total Elapsed Time:   9.2000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4535E-02  [K,I,J]   15   49  101
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  102
# Transport Step:   94   Step Size:  0.1000     Total Elapsed Time:   9.3000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4583E-02  [K,I,J]   15   43  102
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   30  103
# Transport Step:   95   Step Size:  9.9999E-02 Total Elapsed Time:   9.4000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4307E-02  [K,I,J]   15   26  102
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25  103
# Transport Step:   96   Step Size:  0.1000     Total Elapsed Time:   9.5000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4524E-02  [K,I,J]   15   32  103
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  103
# Transport Step:   97   Step Size:  0.1000     Total Elapsed Time:   9.6000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4341E-02  [K,I,J]   15   26  103
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25  104
# Transport Step:   98   Step Size:  9.9999E-02 Total Elapsed Time:   9.7000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4584E-02  [K,I,J]   15   30  104
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  104
# Transport Step:   99   Step Size:  0.1000     Total Elapsed Time:   9.8000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3785E-02  [K,I,J]   15   25  104
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  105
# Transport Step:  100   Step Size:  9.9999E-02 Total Elapsed Time:   9.9000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4271E-02  [K,I,J]   15   30  105
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  105
# Transport Step:  101   Step Size:  0.1000     Total Elapsed Time:   10.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4561E-02  [K,I,J]   15   51  105
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34   78
# Transport Step:  102   Step Size:  0.1000     Total Elapsed Time:   10.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4429E-02  [K,I,J]   15   28  106
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   27  107
# Transport Step:  103   Step Size:  9.9999E-02 Total Elapsed Time:   10.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4487E-02  [K,I,J]   15   35  107
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  107
# Transport Step:  104   Step Size:  0.1000     Total Elapsed Time:   10.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4456E-02  [K,I,J]   15   48  107
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  108
# Transport Step:  105   Step Size:  9.9999E-02 Total Elapsed Time:   10.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4532E-02  [K,I,J]   15   38  108
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  108
# Transport Step:  106   Step Size:  0.1000     Total Elapsed Time:   10.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4298E-02  [K,I,J]   15   49  108
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  109
# Transport Step:  107   Step Size:  0.1000     Total Elapsed Time:   10.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4420E-02  [K,I,J]   15   43  109
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  109
# Transport Step:  108   Step Size:  9.9999E-02 Total Elapsed Time:   10.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4181E-02  [K,I,J]   15   26  109
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25  110
# Transport Step:  109   Step Size:  0.1000     Total Elapsed Time:   10.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4333E-02  [K,I,J]   15   44  110
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  110
# Transport Step:  110   Step Size:  9.9999E-02 Total Elapsed Time:   10.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4237E-02  [K,I,J]   15   50  110
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25  111
# Transport Step:  111   Step Size:  0.1000     Total Elapsed Time:   11.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4444E-02  [K,I,J]   15   30  111
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   29  112
# Transport Step:  112   Step Size:  0.1000     Total Elapsed Time:   11.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3566E-02  [K,I,J]   15   25  111
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  112
# Transport Step:  113   Step Size:  9.9999E-02 Total Elapsed Time:   11.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4106E-02  [K,I,J]   15   30  112
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   28  113
# Transport Step:  114   Step Size:  0.1000     Total Elapsed Time:   11.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4378E-02  [K,I,J]   15   51  112
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  113
# Transport Step:  115   Step Size:  9.9999E-02 Total Elapsed Time:   11.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4264E-02  [K,I,J]   15   28  113
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   28  114
# Transport Step:  116   Step Size:  0.1000     Total Elapsed Time:   11.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4363E-02  [K,I,J]   15   41  114
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  114
# Transport Step:  117   Step Size:  0.1000     Total Elapsed Time:   11.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4295E-02  [K,I,J]   15   48  114
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   27  115
# Transport Step:  118   Step Size:  9.9999E-02 Total Elapsed Time:   11.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4371E-02  [K,I,J]   15   38  115
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  115
# Transport Step:  119   Step Size:  0.1000     Total Elapsed Time:   11.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4137E-02  [K,I,J]   15   27  115
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   27  116
# Transport Step:  120   Step Size:  9.9999E-02 Total Elapsed Time:   11.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4249E-02  [K,I,J]   15   43  116
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  116
# Transport Step:  121   Step Size:  0.1000     Total Elapsed Time:   12.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4022E-02  [K,I,J]   15   26  116
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  117
# Transport Step:  122   Step Size:  0.1000     Total Elapsed Time:   12.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4170E-02  [K,I,J]   15   32  117
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   31  118
# Transport Step:  123   Step Size:  9.9999E-02 Total Elapsed Time:   12.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4089E-02  [K,I,J]   15   50  117
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  118
# Transport Step:  124   Step Size:  0.1000     Total Elapsed Time:   12.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4338E-02  [K,I,J]   15   30  118
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   30  119
# Transport Step:  125   Step Size:  9.9999E-02 Total Elapsed Time:   12.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3415E-02  [K,I,J]   15   51  118
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  119
# Transport Step:  126   Step Size:  0.1000     Total Elapsed Time:   12.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3951E-02  [K,I,J]   15   30  119
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   29  120
# Transport Step:  127   Step Size:  0.1000     Total Elapsed Time:   12.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4215E-02  [K,I,J]   15   25  119
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  120
# Transport Step:  128   Step Size:  9.9999E-02 Total Elapsed Time:   12.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4125E-02  [K,I,J]   15   28  120
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   28  121
# Transport Step:  129   Step Size:  0.1000     Total Elapsed Time:   12.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4243E-02  [K,I,J]   15   35  121
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  121
# Transport Step:  130   Step Size:  9.9999E-02 Total Elapsed Time:   12.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4164E-02  [K,I,J]   15   48  121
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   47  123
# Transport Step:  131   Step Size:  0.1000     Total Elapsed Time:   13.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4222E-02  [K,I,J]   15   38  122
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  122
# Transport Step:  132   Step Size:  0.1000     Total Elapsed Time:   13.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3971E-02  [K,I,J]   15   49  122
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   48  124
# Transport Step:  133   Step Size:  9.9999E-02 Total Elapsed Time:   13.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4087E-02  [K,I,J]   15   33  123
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  123
# Transport Step:  134   Step Size:  0.1000     Total Elapsed Time:   13.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3328E-02  [K,I,J]   15   49  123
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  124
# Transport Step:  135   Step Size:  9.9999E-02 Total Elapsed Time:   13.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3953E-02  [K,I,J]   15   32  124
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   30  126
# Transport Step:  136   Step Size:  0.1000     Total Elapsed Time:   13.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3931E-02  [K,I,J]   15   26  124
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  125
# Transport Step:  137   Step Size:  0.1000     Total Elapsed Time:   13.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4225E-02  [K,I,J]   15   30  125
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   29  127
# Transport Step:  138   Step Size:  9.9999E-02 Total Elapsed Time:   13.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3006E-02  [K,I,J]   15   26  125
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34   98
# Transport Step:  139   Step Size:  0.1000     Total Elapsed Time:   13.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4241E-02  [K,I,J]   15   30  126
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   28  128
# Transport Step:  140   Step Size:  9.9999E-02 Total Elapsed Time:   13.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4073E-02  [K,I,J]   15   51  126
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  127
# Transport Step:  141   Step Size:  0.1000     Total Elapsed Time:   14.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3739E-02  [K,I,J]   15   47  127
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   28  129
# Transport Step:  142   Step Size:  0.1000     Total Elapsed Time:   14.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4109E-02  [K,I,J]   15   35  128
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  128
# Transport Step:  143   Step Size:  9.9999E-02 Total Elapsed Time:   14.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3996E-02  [K,I,J]   15   28  128
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   47  130
# Transport Step:  144   Step Size:  0.1000     Total Elapsed Time:   14.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4080E-02  [K,I,J]   15   38  129
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  129
# Transport Step:  145   Step Size:  9.9999E-02 Total Elapsed Time:   14.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3807E-02  [K,I,J]   15   27  129
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   47  131
# Transport Step:  146   Step Size:  0.1000     Total Elapsed Time:   14.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4007E-02  [K,I,J]   15   35  130
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  130
# Transport Step:  147   Step Size:  0.1000     Total Elapsed Time:   14.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3778E-02  [K,I,J]   15   27  130
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  132
# Transport Step:  148   Step Size:  9.9999E-02 Total Elapsed Time:   14.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3816E-02  [K,I,J]   15   32  131
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   30  133
# Transport Step:  149   Step Size:  0.1000     Total Elapsed Time:   14.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3810E-02  [K,I,J]   15   26  131
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   49  133
# Transport Step:  150   Step Size:  9.9999E-02 Total Elapsed Time:   14.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4100E-02  [K,I,J]   15   46  132
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   29  134
# Transport Step:  151   Step Size:  0.1000     Total Elapsed Time:   15.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3322E-02  [K,I,J]   15   26  132
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  133
# Transport Step:  152   Step Size:  0.1000     Total Elapsed Time:   15.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4112E-02  [K,I,J]   15   30  133
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   28  135
# Transport Step:  153   Step Size:  9.9999E-02 Total Elapsed Time:   15.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3938E-02  [K,I,J]   15   25  133
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  134
# Transport Step:  154   Step Size:  0.1000     Total Elapsed Time:   15.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3611E-02  [K,I,J]   15   29  134
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   28  136
# Transport Step:  155   Step Size:  9.9999E-02 Total Elapsed Time:   15.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3964E-02  [K,I,J]   15   38  135
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  135
# Transport Step:  156   Step Size:  0.1000     Total Elapsed Time:   15.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3833E-02  [K,I,J]   15   28  135
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   27  137
# Transport Step:  157   Step Size:  0.1000     Total Elapsed Time:   15.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3959E-02  [K,I,J]   15   38  136
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   32  138
# Transport Step:  158   Step Size:  9.9999E-02 Total Elapsed Time:   15.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3659E-02  [K,I,J]   15   27  136
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  138
# Transport Step:  159   Step Size:  0.1000     Total Elapsed Time:   15.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3825E-02  [K,I,J]   15   35  137
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   31  139
# Transport Step:  160   Step Size:  9.9999E-02 Total Elapsed Time:   15.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3639E-02  [K,I,J]   15   27  137
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  139
# Transport Step:  161   Step Size:  0.1000     Total Elapsed Time:   16.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3730E-02  [K,I,J]   15   31  138
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   30  140
# Transport Step:  162   Step Size:  0.1000     Total Elapsed Time:   16.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3736E-02  [K,I,J]   15   26  138
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25  140
# Transport Step:  163   Step Size:  0.1000     Total Elapsed Time:   16.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3993E-02  [K,I,J]   15   46  139
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   29  141
# Transport Step:  164   Step Size:  9.9998E-02 Total Elapsed Time:   16.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3237E-02  [K,I,J]   15   50  139
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25  141
# Transport Step:  165   Step Size:  0.1000     Total Elapsed Time:   16.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3987E-02  [K,I,J]   15   30  140
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   28  142
# Transport Step:  166   Step Size:  0.1000     Total Elapsed Time:   16.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3787E-02  [K,I,J]   15   25  140
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  141
# Transport Step:  167   Step Size:  0.1000     Total Elapsed Time:   16.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3471E-02  [K,I,J]   15   29  141
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   28  143
# Transport Step:  168   Step Size:  0.1000     Total Elapsed Time:   16.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3861E-02  [K,I,J]   15   38  142
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  142
# Transport Step:  169   Step Size:  9.9998E-02 Total Elapsed Time:   16.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3733E-02  [K,I,J]   15   48  142
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   27  144
# Transport Step:  170   Step Size:  0.1000     Total Elapsed Time:   16.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3835E-02  [K,I,J]   15   38  143
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  143
# Transport Step:  171   Step Size:  0.1000     Total Elapsed Time:   17.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3533E-02  [K,I,J]   15   49  143
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  145
# Transport Step:  172   Step Size:  0.1000     Total Elapsed Time:   17.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3685E-02  [K,I,J]   15   32  144
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   31  146
# Transport Step:  173   Step Size:  0.1000     Total Elapsed Time:   17.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3524E-02  [K,I,J]   15   27  144
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   26  146
# Transport Step:  174   Step Size:  9.9998E-02 Total Elapsed Time:   17.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3621E-02  [K,I,J]   15   31  145
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   30  147
# Transport Step:  175   Step Size:  0.1000     Total Elapsed Time:   17.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3564E-02  [K,I,J]   15   50  145
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25  147
# Transport Step:  176   Step Size:  0.1000     Total Elapsed Time:   17.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3910E-02  [K,I,J]   15   30  146
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   29  148
# Transport Step:  177   Step Size:  0.1000     Total Elapsed Time:   17.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3110E-02  [K,I,J]   15   50  146
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   25  148
# Transport Step:  178   Step Size:  0.1000     Total Elapsed Time:   17.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3820E-02  [K,I,J]   15   30  147
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   28  149
# Transport Step:  179   Step Size:  9.9998E-02 Total Elapsed Time:   17.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3659E-02  [K,I,J]   15   25  147
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  148
# Transport Step:  180   Step Size:  0.1000     Total Elapsed Time:   17.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3250E-02  [K,I,J]   15   29  148
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   45  150
# Transport Step:  181   Step Size:  0.1000     Total Elapsed Time:   18.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4455E-02  [K,I,J]   15   39  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   15   24  149
# Transport Step:  182   Step Size:  0.1000     Total Elapsed Time:   18.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4246E-02  [K,I,J]   15   48  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   15   53  149
# Transport Step:  183   Step Size:  0.1000     Total Elapsed Time:   18.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3682E-02  [K,I,J]   15   25  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   15   24  150
# Transport Step:  184   Step Size:  9.9998E-02 Total Elapsed Time:   18.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3578E-02  [K,I,J]   14   36  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   10   34  140
# Transport Step:  185   Step Size:  0.1000     Total Elapsed Time:   18.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3646E-02  [K,I,J]   14   32  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   10   30  140
# Transport Step:  186   Step Size:  0.1000     Total Elapsed Time:   18.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3330E-02  [K,I,J]   14   28  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   13   28  150
# Transport Step:  187   Step Size:  0.1000     Total Elapsed Time:   18.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3299E-02  [K,I,J]   14   49  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   10   36  142
# Transport Step:  188   Step Size:  0.1000     Total Elapsed Time:   18.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2644E-02  [K,I,J]   13   35  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   10   20  124
# Transport Step:  189   Step Size:  9.9998E-02 Total Elapsed Time:   18.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3888E-02  [K,I,J]   13   38  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]    9   39  139
# Transport Step:  190   Step Size:  0.1000     Total Elapsed Time:   18.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3999E-02  [K,I,J]   13   37  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   14   54  149
# Transport Step:  191   Step Size:  0.1000     Total Elapsed Time:   19.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3131E-02  [K,I,J]   14   24  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]    9   35  140
# Transport Step:  192   Step Size:  0.1000     Total Elapsed Time:   19.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3093E-02  [K,I,J]   13   48  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3725E-08  [K,I,J]   10   42  146
# Transport Step:  193   Step Size:  0.1000     Total Elapsed Time:   19.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2718E-02  [K,I,J]   12   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]    9   40  141
# Transport Step:  194   Step Size:  9.9998E-02 Total Elapsed Time:   19.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3193E-02  [K,I,J]   14   23  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   15   28  148
# Transport Step:  195   Step Size:  0.1000     Total Elapsed Time:   19.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3020E-02  [K,I,J]   12   43  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   11   19  127
# Transport Step:  196   Step Size:  0.1000     Total Elapsed Time:   19.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3649E-02  [K,I,J]   12   33  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   11   32  150
# Transport Step:  197   Step Size:  0.1000     Total Elapsed Time:   19.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2736E-02  [K,I,J]   13   52  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   13   54  149
# Transport Step:  198   Step Size:  0.1000     Total Elapsed Time:   19.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3098E-02  [K,I,J]   10   38  143
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   11   22  141
# Transport Step:  199   Step Size:  9.9998E-02 Total Elapsed Time:   19.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2627E-02  [K,I,J]   11   34  148
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]   14   17  130
# ...
# Transport Step:  235   Step Size:  0.1000     Total Elapsed Time:   23.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2923E-02  [K,I,J]    7   38  149
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]    9   29  148
# Transport Step:  236   Step Size:  0.1000     Total Elapsed Time:   23.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2740E-02  [K,I,J]    8   41  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]    9   28  148
# Transport Step:  237   Step Size:  0.1000     Total Elapsed Time:   23.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2970E-02  [K,I,J]    8   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]    9   27  148
# Transport Step:  238   Step Size:  0.1000     Total Elapsed Time:   23.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2884E-02  [K,I,J]    8   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7451E-08  [K,I,J]    9   27  148
# Transport Step:  239   Step Size:  9.9998E-02 Total Elapsed Time:   23.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2823E-02  [K,I,J]    8   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    8   35  149
# Transport Step:  240   Step Size:  0.1000     Total Elapsed Time:   23.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3003E-02  [K,I,J]    8   42  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    8   33  149
# Transport Step:  241   Step Size:  0.1000     Total Elapsed Time:   24.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3227E-02  [K,I,J]    8   29  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    8   35  149
# Transport Step:  242   Step Size:  0.1000     Total Elapsed Time:   24.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3529E-02  [K,I,J]    8   48  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    8   30  149
# Transport Step:  243   Step Size:  0.1000     Total Elapsed Time:   24.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4099E-02  [K,I,J]    8   48  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  148
# Transport Step:  244   Step Size:  9.9998E-02 Total Elapsed Time:   24.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4423E-02  [K,I,J]    8   48  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   37  148
# Transport Step:  245   Step Size:  0.1000     Total Elapsed Time:   24.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4226E-02  [K,I,J]   14   18  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   36  148
# Transport Step:  246   Step Size:  0.1000     Total Elapsed Time:   24.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4333E-02  [K,I,J]    7   40  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   36  149
# Transport Step:  247   Step Size:  0.1000     Total Elapsed Time:   24.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4496E-02  [K,I,J]    7   40  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  149
# Transport Step:  248   Step Size:  0.1000     Total Elapsed Time:   24.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4669E-02  [K,I,J]    7   36  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  149
# Transport Step:  249   Step Size:  9.9998E-02 Total Elapsed Time:   24.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4963E-02  [K,I,J]    7   40  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   41  148
# Transport Step:  250   Step Size:  0.1000     Total Elapsed Time:   24.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5057E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  251   Step Size:  0.1000     Total Elapsed Time:   25.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5098E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  252   Step Size:  0.1000     Total Elapsed Time:   25.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5129E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]   11   19  150
# Transport Step:  253   Step Size:  0.1000     Total Elapsed Time:   25.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5167E-02  [K,I,J]    7   40  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   37  148
# Transport Step:  254   Step Size:  9.9998E-02 Total Elapsed Time:   25.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5306E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  255   Step Size:  0.1000     Total Elapsed Time:   25.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5361E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  256   Step Size:  0.1000     Total Elapsed Time:   25.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5390E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  257   Step Size:  0.1000     Total Elapsed Time:   25.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5346E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1467E-07  [K,I,J]   10   23  148
# Transport Step:  258   Step Size:  0.1000     Total Elapsed Time:   25.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5426E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1397E-07  [K,I,J]    7   37  148
# Transport Step:  259   Step Size:  9.9998E-02 Total Elapsed Time:   25.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5503E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  260   Step Size:  0.1000     Total Elapsed Time:   25.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5522E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  261   Step Size:  0.1000     Total Elapsed Time:   26.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5592E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  262   Step Size:  0.1000     Total Elapsed Time:   26.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5611E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  263   Step Size:  0.1000     Total Elapsed Time:   26.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5607E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  264   Step Size:  9.9998E-02 Total Elapsed Time:   26.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5594E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  265   Step Size:  0.1000     Total Elapsed Time:   26.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5528E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  266   Step Size:  0.1000     Total Elapsed Time:   26.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5556E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  267   Step Size:  0.1000     Total Elapsed Time:   26.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5622E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  268   Step Size:  0.1000     Total Elapsed Time:   26.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5554E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  269   Step Size:  9.9998E-02 Total Elapsed Time:   26.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5453E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   39  148
# Transport Step:  270   Step Size:  0.1000     Total Elapsed Time:   26.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5364E-02  [K,I,J]    7   36  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   32  150
# Transport Step:  271   Step Size:  0.1000     Total Elapsed Time:   27.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5359E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   32  150
# Transport Step:  272   Step Size:  0.1000     Total Elapsed Time:   27.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5395E-02  [K,I,J]    7   33  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   32  150
# Transport Step:  273   Step Size:  0.1000     Total Elapsed Time:   27.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5361E-02  [K,I,J]    7   33  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   32  150
# Transport Step:  274   Step Size:  9.9998E-02 Total Elapsed Time:   27.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5238E-02  [K,I,J]    7   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  148
# Transport Step:  275   Step Size:  0.1000     Total Elapsed Time:   27.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5039E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  148
# Transport Step:  276   Step Size:  0.1000     Total Elapsed Time:   27.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5145E-02  [K,I,J]    7   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  148
# Transport Step:  277   Step Size:  0.1000     Total Elapsed Time:   27.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5124E-02  [K,I,J]    7   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  149
# Transport Step:  278   Step Size:  0.1000     Total Elapsed Time:   27.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5193E-02  [K,I,J]    7   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   36  148
# Transport Step:  279   Step Size:  9.9998E-02 Total Elapsed Time:   27.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5026E-02  [K,I,J]    7   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   36  148
# Transport Step:  280   Step Size:  0.1000     Total Elapsed Time:   27.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5025E-02  [K,I,J]    7   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   31  149
# Transport Step:  281   Step Size:  0.1000     Total Elapsed Time:   28.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5059E-02  [K,I,J]    7   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   31  149
# Transport Step:  282   Step Size:  0.1000     Total Elapsed Time:   28.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4618E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  148
# Transport Step:  283   Step Size:  0.1000     Total Elapsed Time:   28.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4739E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  149
# Transport Step:  284   Step Size:  9.9998E-02 Total Elapsed Time:   28.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4782E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  149
# Transport Step:  285   Step Size:  0.1000     Total Elapsed Time:   28.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4879E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   36  148
# Transport Step:  286   Step Size:  0.1000     Total Elapsed Time:   28.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4699E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  148
# Transport Step:  287   Step Size:  0.1000     Total Elapsed Time:   28.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4577E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  148
# Transport Step:  288   Step Size:  0.1000     Total Elapsed Time:   28.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4760E-02  [K,I,J]    7   43  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   31  149
# Transport Step:  289   Step Size:  9.9998E-02 Total Elapsed Time:   28.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4817E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   34  148
# Transport Step:  290   Step Size:  0.1000     Total Elapsed Time:   28.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4712E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   36  148
# Transport Step:  291   Step Size:  0.1000     Total Elapsed Time:   29.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4509E-02  [K,I,J]    7   35  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   36  148
# Transport Step:  292   Step Size:  0.1000     Total Elapsed Time:   29.100
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4755E-02  [K,I,J]    7   35  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   36  148
# Transport Step:  293   Step Size:  0.1000     Total Elapsed Time:   29.200
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4753E-02  [K,I,J]    7   35  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   36  148
# Transport Step:  294   Step Size:  9.9998E-02 Total Elapsed Time:   29.300
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4701E-02  [K,I,J]    7   35  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    6   37  149
# Transport Step:  295   Step Size:  0.1000     Total Elapsed Time:   29.400
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4833E-02  [K,I,J]    7   36  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   36  148
# Transport Step:  296   Step Size:  0.1000     Total Elapsed Time:   29.500
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4754E-02  [K,I,J]    7   36  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   37  148
# Transport Step:  297   Step Size:  0.1000     Total Elapsed Time:   29.600
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4627E-02  [K,I,J]    7   36  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   37  148
# Transport Step:  298   Step Size:  0.1000     Total Elapsed Time:   29.700
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4368E-02  [K,I,J]    8   49  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   37  148
# Transport Step:  299   Step Size:  9.9998E-02 Total Elapsed Time:   29.800
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4644E-02  [K,I,J]    7   38  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   35  148
# Transport Step:  300   Step Size:  0.1000     Total Elapsed Time:   29.900
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4698E-02  [K,I,J]    7   36  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   35  148
# Transport Step:  301   Step Size:  0.1000     Total Elapsed Time:   30.000
# Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4640E-02  [K,I,J]    7   36  150
# Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-07  [K,I,J]    7   37  148
#
# Program completed.   Total CPU time:  001 minutes 57.156 seconds

# %%
# output

groundwaterflowfield = True
contaminantplumefield = True
breakthroughcurve = True
arrivaltimedistribution = True

resultvisulization(groundwaterflowfield, contaminantplumefield, breakthroughcurve, arrivaltimedistribution, inic, degr, conc)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x2188714C5F8>
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x2188714CB00>
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x2188714C2E8>
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x2188714CD30>

# %%
def simulation(MODFLOW, MT3MDS, case, hydr, rech, inic, degr, conc):
    
    if MODFLOW == True:
        # aquifer size
        delx = 1
        dely = 1
        delz = 1
        lambdax = 25
        lambday = 25
        lambdaz = 5
        nlay = lambdaz*3
        nrow = lambday*3
        ncol = lambdax*6
        ztop = 0.
        zbot = np.zeros((nlay, nrow, ncol))
        for i in range(nlay):
            zbot[i, :, :] = ztop - delz*(i+1)

        # flow boundary condition
        ibound = np.ones((nlay, nrow, ncol), dtype=np.int32)
        ibound[:, :, 0] = -1
        ibound[:, :, -1] = -1
        headend = hydr*ncol
        strt = np.ones((nlay, nrow, ncol), dtype=np.float32)
        strt[:, :, 0] = headend
        strt[:, :, -1] = 0
        lrcq = {}
        lrcq[0] = []
        for i in range(lambdax,lambdax*2):
            for j in range(lambday,lambday*2):
                lrcq[0].append([nlay-1, j, i, rech])

        # contamination source
        initial=np.zeros((nlay,nrow,ncol))
        for i in range(lambdax,lambdax*2):
            for j in range(lambday,lambday*2):
                initial[nlay-1, j, i] = inic

        # time domain            
        tlim=int(conc)
        times=np.linspace(0, tlim, num=tlim*10 + 1)

        # aquifer case
        if case == 1:
            hk = np.ones((nlay, nrow, ncol))
        elif case == 2:
            sgems=np.loadtxt('aquifer1', skiprows=1, delimiter=',')
            aquifer=np.zeros((nlay,nrow,ncol))
            aquifer=np.reshape(sgems.T,(nlay,nrow,ncol))
            hk = np.exp(aquifer)
        elif case == 3:
            sgems=np.loadtxt('aquifer2', skiprows=1, delimiter=',')
            aquifer=np.zeros((nlay,nrow,ncol))
            aquifer=np.reshape(sgems.T,(nlay,nrow,ncol))
            hk = np.exp(aquifer)        
        else:
            print('wrong case number')

        # MODFLOW2005
        modelname = 'aquifer'
        mf = flopy.modflow.Modflow(modelname, exe_name='MF2005.1_12/bin/mf2005dbl' )
        dis = flopy.modflow.ModflowDis(mf, nlay=nlay, nrow=nrow, ncol=ncol, delr=delx, delc=dely, top=ztop, botm=zbot, nper=1, perlen=tlim)
        bas = flopy.modflow.ModflowBas(mf, ibound=ibound, strt=strt)
        lpf = flopy.modflow.ModflowLpf(mf, hk=hk)
        wel = flopy.modflow.ModflowWel(mf, stress_period_data=lrcq)
        oc = flopy.modflow.ModflowOc(mf)
        pcg = flopy.modflow.ModflowPcg(mf)
        lmt = flopy.modflow.ModflowLmt(mf, output_file_header='extended', output_file_format='formatted', output_file_name=modelname+".ftl")
        mf.write_input()
        success, buff = mf.run_model()

        if MT3MDS == True:
            # MODFLOW2005 to MT3DMS
            f = open('aquifer.ftl', 'r')
            cell_number = nlay * nrow * ncol
            velocity_vector = np.zeros((cell_number,3))
            for line in f:
                if line[3] == 'X':
                    print(line)
                    subline = f.readline().split()
                    for j in range(cell_number):
                        velocity_vector[j, 0] = float(subline[j])

                if line[3] == 'Y':
                    print(line)
                    subline = f.readline().split()
                    for j in range(cell_number):
                        velocity_vector[j, 1] = float(subline[j])

                if line[3] == 'Z':
                    print(line)
                    subline = f.readline().split()
                    for j in range(cell_number):
                        velocity_vector[j, 2] = float(subline[j])
            f.close()

            # MT3DMS
            mt = flopy.mt3d.Mt3dms(modflowmodel=mf, modelname=modelname, namefile_ext='mtnam',
                                   exe_name='mt3dms5/bin/mt3dms5b', ftlfree=True, ftlfilename=modelname+".ftl")
            btn=flopy.mt3d.Mt3dBtn(mt,prsity=0.4, sconc=initial, ncomp=1, nprs=1, timprs=times, savucn=True)
            adv = flopy.mt3d.Mt3dAdv(mt, mixelm=3, percel=0.75, mxpart=8000000)
            dsp = flopy.mt3d.Mt3dDsp(mt, al=0.01, trpt=0.1, trpv=0.01, dmcoef=1e-9)
            rct = flopy.mt3d.Mt3dRct(mt,isothm=0, igetsc=0)
            ssm = flopy.mt3d.Mt3dSsm(mt)
            gcg = flopy.mt3d.Mt3dGcg(mt)
            mt.write_input()
            success, buff=mt.run_model()

# %%
def resultvisulization(groundwaterflowfield, contaminantplumefield, breakthroughcurve, arrivaltimedistribution, inic, degr, conc):
    f = open('aquifer.ftl', 'r')
    delx = 1
    dely = 1
    delz = 1
    lambdax = 25
    lambday = 25
    lambdaz = 5
    nlay = lambdaz*3
    nrow = lambday*3
    ncol = lambdax*6
    cell_number = nlay * nrow * ncol
    velocity_vector = np.zeros((cell_number,3))
    for line in f:
        if line[3] == 'X':
            print(line)
            subline = f.readline().split()
            for j in range(cell_number):
                velocity_vector[j, 0] = float(subline[j])

        if line[3] == 'Y':
            print(line)
            subline = f.readline().split()
            for j in range(cell_number):
                velocity_vector[j, 1] = float(subline[j])

        if line[3] == 'Z':
            print(line)
            subline = f.readline().split()
            for j in range(cell_number):
                velocity_vector[j, 2] = float(subline[j])
    f.close()
    factor = 27/np.quantile(velocity_vector, 0.99)
    vgrid = np.zeros((cell_number, 3))
    wellgrid = np.zeros((lambdax*lambday, 3))
    cpgrid = np.zeros((nlay*nrow, 3))
    iteration = 0
    deltal = 1
    for l in range(nlay):
        for k in range(nrow):
            for j in range(ncol):
                vgrid[iteration] = np.array(([j*deltal,k*deltal,l*deltal]))
                iteration += 1            
    iteration = 0        
    for l in range(lambdax, lambdax*2):
        for k in range(lambday, lambday*2):
            wellgrid[iteration] = np.array(([l*deltal,k*deltal,(nlay-1)*deltal]))
            iteration += 1
    iteration = 0        
    for l in range(lambday*3):
        for k in range(lambdaz*3):
            cpgrid[iteration] = np.array(([5*lambdax*deltal,l*deltal,k*deltal]))
            iteration += 1
    
    if groundwaterflowfield == True:
        rawgrid = vgrid.reshape((15,75,150,3))
        rawvelo = velocity_vector.reshape((15,75,150,3))
        avgrid = np.zeros((3,5,10,3))
        avvelo = np.zeros((3,5,10,3))
        for i in range(10):
            for j in range(5):
                for k in range(3):
                    avblock = rawgrid[5*k:(5*k+5),15*j:(15*j+15),15*i:(15*i+15)].reshape((15*15*5,3))
                    avgrid[k,j,i] = [np.mean([avblock[i][0] for i in range(15*15*5)]),
                                     np.mean([avblock[i][1] for i in range(15*15*5)]),
                                     np.mean([avblock[i][2] for i in range(15*15*5)])]
                    avblock = rawvelo[5*k:(5*k+5),15*j:(15*j+15),15*i:(15*i+15)].reshape((15*15*5,3))
                    avvelo[k,j,i] = [np.mean([avblock[i][0] for i in range(15*15*5)]),
                                     np.mean([avblock[i][1] for i in range(15*15*5)]),
                                     np.mean([avblock[i][2] for i in range(15*15*5)])]
        avgrid = avgrid.reshape((10*5*3, 3))
        avvelo = avvelo.reshape((10*5*3, 3))        

        point_cloud = pv.PolyData(avgrid)
        point_cloud['vectors'] = avvelo
        arrows = point_cloud.glyph(orient='vectors', scale=True, factor=factor)
        plotter = pv.Plotter()
        plotter.add_text('Groundwater flow vectors',position='upper_edge', font='arial', font_size=10, color='k')
        sargs = dict(
            title_font_size=1,
            label_font_size=1,
            n_labels=5,
            fmt="%.1f",
            color ='k',
            font_family="arial")
        plotter.add_mesh(arrows, scalars='GlyphScale', lighting=True, show_scalar_bar=True, 
                         stitle='Groundwater flow [L3/T]' , scalar_bar_args=sargs, opacity=0.8)
        plotter.enable_eye_dome_lighting()
        plotter.set_background('w')
        welldata = pv.PolyData(wellgrid)
        outline = welldata.outline()
        plotter.add_mesh(outline, color="blue", line_width=6, label='recharge zone')
        cpdata = pv.PolyData(cpgrid)
        outline2 = cpdata.outline()
        plotter.add_mesh(outline2, color="green", line_width=6, label='control plane')
        plotter.show_bounds(bounds=[0, 150, 0, 75, 0, 15], grid='back', location='outer', xlabel = 'x [L]', ylabel = 'y [L]', 
                            zlabel = 'z [L]', italic=True, font_family="arial", font_size=12)
        plotter.add_legend(bcolor=[255,255,255], border=True, size=[0.15,0.06])
        plotter.show()
        plotter.screenshot(filename='groundwaterflowfield.png', transparent_background=True)
 
    if contaminantplumefield == True:
        c=bf.UcnFile('MT3D001.UCN')
        cpoint_cloud = pv.PolyData(vgrid)
        ctimes = c.get_times()
        screenshots = [ctimes[0], ctimes[int(len(ctimes)/2)], ctimes[-1]]

        for i in range(3):
            cfield = c.get_data(totim=screenshots[i]).flatten()
            cpoint_cloud = pv.PolyData(vgrid)
            plotter = pv.Plotter()
            plotter.add_text('Contaminant plume at t = '+str(screenshots[i])+' [T]',position='upper_edge', font='arial', font_size=10, color='k')
            sargs = dict(
                title_font_size=1,
                label_font_size=1,
                n_labels=5,
                fmt="%.3f",
                color ='k',
                font_family="arial")
            welldata = pv.PolyData(wellgrid)
            outline = welldata.outline()
            plotter.add_mesh(outline, color="blue", line_width=6, label='recharge zone')
            cpdata = pv.PolyData(cpgrid)
            outline2 = cpdata.outline()
            plotter.add_mesh(outline2, color="green", line_width=6, label='control plane')
            plotter.add_mesh(cpoint_cloud, scalars=cfield, show_scalar_bar=True, lighting=True, point_size=7, 
                             render_points_as_spheres=True, opacity='linear',
                             stitle='Contaminant concentration [M/L3]' , scalar_bar_args=sargs, cmap='bone_r' )
            plotter.show_bounds(bounds=[0, 150, 0, 75, 0, 15], grid='back', location='outer', xlabel = 'x [L]', ylabel = 'y [L]', 
                                zlabel = 'z [L]', italic=True, font_family="arial", font_size=12)
            plotter.enable_eye_dome_lighting()
            plotter.set_background('w')
            plotter.add_legend(bcolor=[255,255,255], border=True, size=[0.15,0.06])
            plotter.show()
            plotter.screenshot(filename='contaminanttransport'+str(i)+'.png', transparent_background=True)
            
            
    if breakthroughcurve == True:
        c=bf.UcnFile('MT3D001.UCN')
        ctimes = c.get_times()

        for k in range(len(ctimes)):
            concentration=c.get_data(totim=ctimes[k])
            if np.sum(concentration[:,:,lambdax*5]) >= 0.001:
                initime = ctimes[k]
                initk = k
                break

        concen = np.zeros(len(ctimes))
        init = np.sum(c.get_data(totim=initime)[:,:,:lambdax*5])
        cpc = 0

        for k in range(initk,len(ctimes)):
            concentration=c.get_data(totim=ctimes[k])
            cpc = (init - np.sum(concentration[:,:,:lambdax*5]))/init
            concen[k] = cpc

        fig, ax = plt.subplots(figsize=(5,4))
        ax.title.set_text('Breakthrough curve at control plane')
        ax.plot(ctimes, concen, color='k', linewidth=5)
        plt.xlabel(r'$t$ [T]', size=16)
        plt.ylabel(r'$M/M_0$', size=16)
        plt.xticks(size=14)
        plt.yticks(size=14)
        plt.xticks(fontsize=14, fontname='Arial')
        plt.yticks(fontsize=14, fontname='Arial')
        ax.xaxis.set_major_locator(MultipleLocator(int(conc/5)))
        ax.xaxis.set_minor_locator(MultipleLocator(int(conc/25)))
        ax.yaxis.set_major_locator(MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(MultipleLocator(0.04))
        plt.yticks(fontsize=14, fontname='Arial')
        ax.tick_params(which="major", direction="in", right=True, top=True, length=5)
        ax.tick_params(which="minor", direction="in", right=True, top=True, length=3)
        plt.ylim(0,1)
        plt.xlim(0,conc)
        plt.tight_layout()
        plt.savefig('breakthroughcurve.png',dpi=400)
        plt.show()

    if arrivaltimedistribution == True:
        c=bf.UcnFile('MT3D001.UCN')
        ctimes = c.get_times()
        
        for k in range(len(ctimes)):
            concentration=c.get_data(totim=ctimes[k])
            if np.sum(concentration[:,:,lambdax*5]) >= 0.001:
                initime = ctimes[k]
                initk = k
                break

        concen = np.zeros(len(ctimes))
        init = np.sum(c.get_data(totim=initime)[:,:,:lambdax*5])
        cpc = 0

        for k in range(initk,len(ctimes)):
            concentration=c.get_data(totim=ctimes[k])
            cpc = (init - np.sum(concentration[:,:,:lambdax*5]))/init
            concen[k] = cpc        
        
        intpx = []
        intpy = []

        for i in range(len(ctimes)):
            if concen[i] >= 0.01:
                if concen[i] >= 0.99:
                    break
                intpx.append(concen[i])
                intpy.append(ctimes[i])
        intpx = np.asarray(intpx)
        intpy = np.asarray(intpy)

        f1 = interp1d(intpx, intpy, kind='quadratic')
        newconc = np.linspace(intpx.min(), intpx.max(), num=51)
        newtime = f1(newconc)

        fig, ax = plt.subplots(figsize=(5,4))
        ax.title.set_text('Arrival time distribution at control plane')
        histdata = ax.hist(newtime, 20, color='k', density=True)
        ax.vlines(inic/degr,0,np.max(histdata[0]), color='red', label='time for 100% decay')
        ax.hist(newtime, 20, color='k', density=True)
        plt.xlabel(r'$t_{arrival}$ [T]', size=16)
        plt.ylabel(r'Probability density', size=16)
        plt.xticks(size=14)
        plt.yticks(size=14)
        plt.legend(fontsize=12)
        plt.tight_layout()
        plt.savefig('arrivaltime.png',dpi=400)
        plt.show()
